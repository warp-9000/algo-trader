# %% [markdown]
# Pandas Datareader
# https://pandas-datareader.readthedocs.io/en/latest/

# %%
#Import dictionaries and libraries
#Pandas Datareader prepares the data in a dataframe for you
#To install Pandas Datareder pip install pandas-datareader
import pandas_datareader as pdr
import datetime as dt

# %%
ticker_symbols = ["SPY", "META", "AAPL", "AMZN", "NFLX", "GOOG", "MSFT"]
start = dt.datetime(2002,3,1)
end = dt.datetime(2022,6,30)
data = pdr.get_data_yahoo(ticker_symbols, start).dropna()

# %%
data.head()
# Out:
# Attributes   Adj Close                                                         \
# Symbols            SPY       META       AAPL       AMZN       NFLX       GOOG
# Date
# 2014-03-27  158.455826  60.970001  17.075377  16.923500  52.025715  27.846546
# 2014-03-28  159.237076  60.009998  17.056313  16.914499  51.267143  27.922838
# 2014-03-31  160.541962  60.240002  17.052500  16.818501  50.290001  27.772251
# 2014-04-01  161.606491  62.619999  17.208494  17.149500  52.098572  28.280355
# 2014-04-02  162.147308  62.720001  17.237087  17.098000  51.840000  28.272379
#
# Attributes                  Close                        ...       Open  \
# Symbols          MSFT         SPY       META       AAPL  ...       NFLX
# Date                                                     ...
# 2014-03-27  33.854599  184.580002  60.970001  19.195000  ...  53.001431
# 2014-03-28  34.663113  185.490005  60.009998  19.173571  ...  51.459999
# ...

# %%
data.tail()
# Out:
# Attributes   Adj Close                                                  \
# Symbols            SPY        META        AAPL        AMZN        NFLX
# Date
# 2022-07-12  380.829987  163.270004  145.860001  109.220001  174.449997
# 2022-07-13  378.829987  163.490005  145.490005  110.400002  176.559998
# 2022-07-14  377.910004  158.050003  148.470001  110.629997  174.779999
# 2022-07-15  385.130005  164.699997  150.169998  113.550003  189.110001
# 2022-07-18  381.950012  167.229996  147.070007  113.760002  190.919998
#
# Attributes                               Close                          ...  \
# Symbols           GOOG        MSFT         SPY        META        AAPL  ...
# Date                                                                    ...
# 2022-07-12  114.849503  253.669998  380.829987  163.270004  145.860001  ...
# 2022-07-13  112.186996  252.720001  378.829987  163.490005  145.490005  ...
# 2022-07-14  111.440002  254.080002  377.910004  158.050003  148.470001  ...
# ...

# %%
data.tail()
# Out:
# Attributes   Adj Close                                                  \
# Symbols            SPY        META        AAPL        AMZN        NFLX
# Date
# 2022-07-12  380.829987  163.270004  145.860001  109.220001  174.449997
# 2022-07-13  378.829987  163.490005  145.490005  110.400002  176.559998
# 2022-07-14  377.910004  158.050003  148.470001  110.629997  174.779999
# 2022-07-15  385.130005  164.699997  150.169998  113.550003  189.110001
# 2022-07-18  381.950012  167.229996  147.070007  113.760002  190.919998
#
# Attributes                               Close                          ...  \
# Symbols           GOOG        MSFT         SPY        META        AAPL  ...
# Date                                                                    ...
# 2022-07-12  114.849503  253.669998  380.829987  163.270004  145.860001  ...
# 2022-07-13  112.186996  252.720001  378.829987  163.490005  145.490005  ...
# 2022-07-14  111.440002  254.080002  377.910004  158.050003  148.470001  ...
# ...
